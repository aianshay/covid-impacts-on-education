# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"""works for year > 2010"""

def create_filtered_dataset_fail_2011_2020(year):
    df = pd.read_excel(f'data/tx_rend_brasil_regioes_ufs_{year}.xlsx', skiprows=5)
    
    #selecting columns
    df = df.iloc[:,:40]
    
    #naming columns
    df.columns = ['Ano', 'Unidade Geográfica', 'Localização',
                  'Rede', 'Total - EF', 'Anos Iniciais - EF',
                  'Anos Finais - EF', '1EF', '2EF', '3EF', '4EF', '5EF', '6EF', '7EF',
                  '8EF', '9EF', 'Total - EM', '1EM', '2EM', '3EM', '4EM', 'Não-Seriado', 
                  'R_EF_Total', 'R_EF_Anos Iniciais', 'R_EF_Anos Finais', 'R1EF', 'R2EF', 
                  'R3EF', '4REF', 'R5EF', 'R6EF', 'R7EF','R8EF', 'R9EF', 
                  'RTotal - EM', 'R1EM', 'R2EM', 'R3EM', 'R4EM', 'RNão-Seriado',]
    
    df = df.iloc[3:,:]
    df = df.loc[:20,:]
    df.drop(columns=['Unidade Geográfica', 'Total - EF', 'Anos Iniciais - EF',
                  'Anos Finais - EF', '1EF', '2EF', '3EF', '4EF', '5EF', '6EF', '7EF',
                  '8EF', '9EF', 'Total - EM', '1EM', '2EM', '3EM', '4EM', 'Não-Seriado', 
                  'R_EF_Anos Iniciais', 'R_EF_Anos Finais',], inplace=True)
    
    return df

# %%
filtered_dataset_fail_2020 = create_filtered_dataset_fail_2011_2020(2020)
filtered_dataset_fail_2020
# Out:
#      Ano Localização       Rede R_EF_Total R1EF R2EF R3EF 4REF R5EF R6EF R7EF  \
# 3   2020       Total      Total        0.8  0.4  0.5  0.7  0.5  0.7    1  1.1
# 4   2020      Urbana      Total        0.8  0.4  0.5  0.7  0.5  0.6  1.1  1.1
# 5   2020       Rural      Total        0.7  0.2  0.3  0.8  0.6  1.1  0.9  0.8
# 6   2020       Total    Federal        0.8  0.6    0  0.2  0.5  0.1  0.6    1
# 7   2020      Urbana    Federal        0.8  0.6    0  0.2  0.5  0.1  0.6    1
# 8   2020       Rural    Federal          0   --    0    0    0    0    0    0
# 9   2020       Total   Estadual        1.3  0.5  0.5  1.2  0.5    1  1.4  1.5
# 10  2020      Urbana   Estadual        1.3  0.5  0.5  1.1  0.5  0.9  1.4  1.5
# 11  2020       Rural   Estadual        1.1  0.3  0.5  1.5  0.8  1.9    1  1.2
# 12  2020       Total  Municipal        0.6  0.2  0.4  0.7  0.5  0.7  0.8  0.8
# 13  2020      Urbana  Municipal        0.6  0.2  0.4  0.7  0.5  0.6  0.8  0.8
# ...

# %%
filtered_dataset_fail_2019 = create_filtered_dataset_fail_2011_2020(2019)
filtered_dataset_fail_2019
# Out:
#      Ano Localização       Rede R_EF_Total R1EF R2EF  R3EF  4REF R5EF  R6EF  \
# 3   2019       Total      Total          6    1  2.1   8.1   5.3  4.7  10.2
# 4   2019      Urbana      Total        5.6    1    2   7.2   4.3  3.8   9.6
# 5   2019       Rural      Total        8.6  1.2  2.7    13  10.6  9.4  14.6
# 6   2019       Total    Federal        4.5  2.2  3.1   3.2   2.2  3.5   4.5
# 7   2019      Urbana    Federal        4.6  2.2  3.1   3.2   2.2  3.5   4.5
# 8   2019       Rural    Federal        2.3    0    0     0     0    0   6.7
# 9   2019       Total   Estadual        6.9  0.6  0.9   7.1   2.9  4.1   9.4
# 10  2019      Urbana   Estadual        6.8  0.4  0.7   6.8   2.6  3.7   9.3
# 11  2019       Rural   Estadual        7.9  2.1  4.2  10.7   7.8  8.6  10.4
# 12  2019       Total  Municipal          7  1.1  2.7    10   6.8  5.7  13.5
# 13  2019      Urbana  Municipal        6.5  1.1  2.7   9.2   5.7  4.7  12.9
# ...

# %%
# filtered_dataset_reprovacao_2019.to_csv(path_or_buf='data/teste.csv', index=False)

# %%
filtered_dataset_fail_2018 = create_filtered_dataset_fail_2011_2020(2018)
filtered_dataset_fail_2018
# Out:
#      Ano Localização       Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2018       Total      Total          7  1.2  2.2   9.4   6.3   5.6  11.7
# 4   2018      Urbana      Total        6.6  1.2  2.1   8.5   5.3   4.5    11
# 5   2018       Rural      Total        9.7  1.4  2.7  14.4  12.1    11  16.2
# 6   2018       Total    Federal        5.3  3.2  4.8   2.8   3.2   2.9   6.6
# 7   2018      Urbana    Federal        5.3  3.3  4.8   2.9   3.2   2.8   6.5
# 8   2018       Rural    Federal        7.1    0    0     0   7.1    20  27.8
# 9   2018       Total   Estadual          8  0.7    1   7.7   3.4   4.4    11
# 10  2018      Urbana   Estadual          8  0.6  0.8   7.4     3     4    11
# 11  2018       Rural   Estadual        8.7  2.3  4.2  11.5   8.4   9.2  11.8
# 12  2018       Total  Municipal        8.1  1.3  2.7  11.8   8.2   6.9  15.1
# 13  2018      Urbana  Municipal        7.6  1.3  2.7    11   7.1   5.7  14.5
# ...

# %%
filtered_dataset_fail_2017 = create_filtered_dataset_fail_2011_2020(2017)
filtered_dataset_fail_2017
# Out:
#      Ano Localização       Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2017       Total      Total        7.4  1.2  2.2   9.7   6.3   5.9  12.7
# 4   2017      Urbana      Total          7  1.2  2.1   8.8   5.2   4.8  12.1
# 5   2017       Rural      Total        9.7  1.4  2.7  14.5  11.8  11.1  16.5
# 6   2017       Total    Federal        5.5  1.8  2.9   4.2   2.8   2.7     7
# 7   2017      Urbana    Federal        5.5  1.8  2.9   4.1   2.7   2.7     7
# 8   2017       Rural    Federal        1.8    0    0    10   7.7     0     0
# 9   2017       Total   Estadual        8.6  0.6  1.1   8.1   3.6   4.5  12.2
# 10  2017      Urbana   Estadual        8.6  0.5  0.9   7.8   3.2   4.1  12.1
# 11  2017       Rural   Estadual          9  2.5  3.9  11.6   8.1   9.3  12.7
# 12  2017       Total  Municipal        8.4  1.3  2.7  12.1     8   7.2    16
# 13  2017      Urbana  Municipal        7.9  1.3  2.7  11.3   6.9   6.1  15.6
# ...

# %%
filtered_dataset_fail_2016 = create_filtered_dataset_fail_2011_2020(2016)
filtered_dataset_fail_2016
# Out:
#      Ano Localização       Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2016       Total      Total        8.3  1.3  2.5  10.7   7.2   6.8    14
# 4   2016       Rural      Total       10.7  1.5    3  15.7  13.1  12.4  17.8
# 5   2016      Urbana      Total        7.9  1.3  2.4   9.7     6   5.7  13.4
# 6   2016       Total   Estadual        9.8  0.7  1.3   8.6   4.1   5.3  13.7
# 7   2016       Total    Federal        5.7  3.4  3.1   3.8   2.8   3.9   6.6
# 8   2016       Total  Municipal        9.3  1.4    3  13.3   9.3   8.3  17.4
# 9   2016       Total    Privada        2.5  1.6  1.3   1.5   1.5   1.6   3.5
# 10  2016       Rural   Estadual        9.3    2  3.9  11.8   8.1   9.3  13.3
# 11  2016      Urbana   Estadual        9.8  0.6  1.1   8.4   3.8     5  13.7
# 12  2016       Rural    Federal        5.3   --    0     0    10  13.3    10
# 13  2016      Urbana    Federal        5.7  3.4  3.1   3.8   2.7   3.8   6.6
# ...

# %%
filtered_dataset_fail_2015 = create_filtered_dataset_fail_2011_2020(2015)
filtered_dataset_fail_2015
# Out:
#      Ano Localização        Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2015       Total       Total        8.2  1.4  2.5  10.5   7.2   6.7  13.8
# 4   2015       Total     Pública        9.2  1.2  2.8  12.2   8.3   7.6  15.4
# 5   2015       Total     Federal        6.3  4.4  3.8   3.1   4.1   3.6   8.6
# 6   2015       Total    Estadual        9.5  0.7  1.3   8.6   4.7   5.5  13.4
# 7   2015       Total   Municipal          9  1.3    3  12.9     9   8.1  17.1
# 8   2015       Total  Particular        2.8  1.8  1.6   1.7   1.7   1.8   4.1
# 9   2015      Urbana       Total        7.8  1.4  2.4   9.6     6   5.6  13.3
# 10  2015      Urbana     Pública          9  1.2  2.7  11.4   7.1   6.5  15.1
# 11  2015      Urbana     Federal        6.3  4.4  3.9   3.1   4.1   3.5   8.6
# 12  2015      Urbana    Estadual        9.5  0.6  1.1   8.4   4.4   5.2  13.4
# 13  2015      Urbana   Municipal        8.7  1.3  3.1  12.2   7.8   6.9  16.8
# ...

# %%
filtered_dataset_fail_2014 = create_filtered_dataset_fail_2011_2020(2014)
filtered_dataset_fail_2014
# Out:
#      Ano Localização    Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2014       Total   Total        8.6  1.5  2.9  11.1   7.6     7  14.6
# 4   2014     Publico   Total        9.6  1.4  3.1  12.8   8.6   7.9  16.2
# 5   2014  Particular   Total        3.2    2  1.8   1.9   1.9     2   4.6
# 6   2014   Municipal   Total        9.5  1.5  3.5  13.5   9.6   8.5  18.1
# 7   2014     Federal   Total        7.8    3  4.2   3.7     3   3.6  10.1
# 8   2014    Estadual   Total        9.8  0.7  1.4   9.2   4.7   5.5    14
# 9   2014       Total   Rural       10.2  1.5  3.5    15  12.7  11.9  17.2
# 10  2014     Publico   Rural       10.2  1.4  3.5  15.1  12.8  11.9  17.3
# 11  2014  Particular   Rural        5.3  4.1  3.1   6.8   4.8   4.6     7
# 12  2014   Municipal   Rural       10.4  1.4  3.4  15.2  13.1  12.1  18.1
# 13  2014     Federal   Rural        3.7    0    0     0   7.1   7.7     0
# 14  2014    Estadual   Rural        9.1  2.5  5.2  12.5   8.6   9.2  12.6
# ...

# %%
filtered_dataset_fail_2013 = create_filtered_dataset_fail_2011_2020(2013)
filtered_dataset_fail_2013
# Out:
#      Ano Localização    Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2013       Total   Total        8.5  1.5  3.3  10.3   7.2   7.3    14
# 4   2013     Publico   Total        9.4  1.4  3.6  11.9   8.2   8.2  15.4
# 5   2013     Privada   Total        3.3  2.1  1.9   1.9   1.9     2   4.7
# 6   2013   Municipal   Total        9.4  1.5    4  12.8     9   8.7  17.8
# 7   2013     Federal   Total        8.2  4.6    4     5   4.6   4.1   8.8
# 8   2013    Estadual   Total        9.4  0.7  1.6   7.6   4.5   6.2  12.7
# 9   2013       Total   Rural        9.8  1.5  4.1    14    12  11.5  16.7
# 10  2013     Publico   Rural        9.9  1.5  4.1    14  12.1  11.6  16.7
# 11  2013     Privada   Rural        4.7  4.1  2.9   6.2   3.6   3.6   6.3
# 12  2013   Municipal   Rural         10  1.4    4  14.2  12.4  11.8  17.6
# 13  2013     Federal   Rural        5.1    0    0     0  21.4   8.3     0
# 14  2013    Estadual   Rural        8.8  1.9    5  11.1   8.3   9.4  12.4
# ...

# %%
filtered_dataset_fail_2012 = create_filtered_dataset_fail_2011_2020(2012)
filtered_dataset_fail_2012
# Out:
#      Ano Localização    Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2012       Total   Total        9.1  1.9  5.1  11.1   7.8   7.5  14.6
# 4   2012     Publico   Total       10.1  1.8  5.7  12.6   8.9   8.4  15.9
# 5   2012     Privada   Total        3.5  2.1    2   1.9   1.9   2.1     5
# 6   2012   Municipal   Total       10.1    2  6.5  13.7   9.7   8.9  17.8
# 7   2012     Federal   Total        8.2  4.4  4.1   4.9   3.9   3.9   9.4
# 8   2012    Estadual   Total         10  0.9  2.2     8   5.3   6.5    14
# 9   2012       Total   Rural       10.8  2.5  7.9  15.2  12.5  11.4    17
# 10  2012     Publico   Rural       10.8  2.5    8  15.3  12.5  11.5    17
# 11  2012     Privada   Rural        5.4    4  4.1   6.5     4   4.3   7.8
# 12  2012   Municipal   Rural         11  2.5  8.1  15.5  12.8  11.7  17.8
# 13  2012     Federal   Rural        9.2    0    0   9.1     0     0  12.5
# 14  2012    Estadual   Rural        9.1  2.7  6.5  11.5   8.6   9.3  13.3
# ...

# %%
filtered_dataset_fail_2011 = create_filtered_dataset_fail_2011_2020(2011)
filtered_dataset_fail_2011
# Out:
#      Ano Localização    Rede R_EF_Total R1EF R2EF  R3EF  4REF  R5EF  R6EF  \
# 3   2011       Total   Total        9.6  2.1  6.7  11.4   7.5   7.8  15.2
# 4   2011     Publico   Total       10.5  2.1  7.5  12.8   8.4   8.6  16.6
# 5   2011  Particular   Total        3.5    2  2.1   1.9   1.9   2.2   4.9
# 6   2011   Municipal   Total       10.2  2.3  8.1  13.8   9.3   9.1  17.9
# 7   2011     Federal   Total        8.6  4.7  4.4   4.6   4.2   5.1  10.1
# 8   2011    Estadual   Total       11.1    1  4.7   8.9   5.2   6.9  15.4
# 9   2011       Total   Rural         11    3  9.8  14.8    12  11.2  17.4
# 10  2011     Publico   Rural         11    3  9.8  14.9  12.1  11.3  17.4
# 11  2011  Particular   Rural        5.7  5.4  5.2   5.8     5   4.8   9.3
# 12  2011   Municipal   Rural       11.1    3  9.9  15.1  12.4  11.4    18
# 13  2011     Federal   Rural        3.3    0    0     0  11.1    10     0
# 14  2011    Estadual   Rural        9.9  2.6  8.6    12   8.7   9.3  14.5
# ...

# %%
"""works for year <= 2010"""

def filtered_dataset_fail_from_2007_2010(year, skiprows=6):
    df = pd.read_excel(f'data/tx_rend_brasil_regioes_ufs_{year}.xlsx', skiprows=skiprows)
    
    #selecting columns
    df = df.iloc[:,:40]
    
    #naming columns
    df.columns = ['Ano', 'Unidade Geográfica', 'Rede',
                  'Localização', '1EF', '2EF', '3EF', '4EF', '5EF', '6EF', '7EF',
                  '8EF', '9EF', 'Anos Iniciais - EF', 'Anos Finais - EF', 'Total - EF',
                  '1EM', '2EM', '3EM', '4EM', 'Não-Seriado', 'Total - EM', 
                  'R1EF', 'R2EF','R3EF', '4REF', 'R5EF', 'R6EF', 'R7EF','R8EF', 'R9EF', 
                  'R_EF_Anos Iniciais', 'R_EF_Anos Finais', 'R_EF_Total',
                  'R1EM', 'R2EM', 'R3EM', 'R4EM', 'RNão-Seriado', 'RTotal - EM',
                  ]
    
    df = df.iloc[3:,:]
    df = df.loc[:20,:]
    df.drop(columns=['Unidade Geográfica', 
                  '1EF', '2EF', '3EF', '4EF', '5EF', '6EF', '7EF',
                  '8EF', '9EF', 'Anos Iniciais - EF', 'Anos Finais - EF', 'Total - EF',
                  '1EM', '2EM', '3EM', '4EM', 'Não-Seriado', 'Total - EM', 
                  'R_EF_Anos Iniciais', 'R_EF_Anos Finais',], inplace=True)
    
    return df

# %%
filtered_dataset_fail_2010 = filtered_dataset_fail_from_2007_2010(2010, skiprows=5)
filtered_dataset_fail_2010
# Out:
#      Ano        Rede Localização R1EF  R2EF  R3EF  4REF  R5EF  R6EF  R7EF  \
# 3   2010    Estadual       Rural  2.8  12.1  12.1   9.6    10  13.5  11.3
# 4   2010    Estadual       Total  1.1   6.9   8.7   5.7   7.6  14.8  13.6
# 5   2010    Estadual      Urbana  0.9   6.5   8.4   5.4   7.4  14.8  13.7
# 6   2010     Federal       Rural    0     0   9.1     0  29.4    10     0
# 7   2010     Federal       Total  3.6   5.5   3.8   4.1   4.8  11.7  12.4
# 8   2010     Federal      Urbana  3.6   5.5   3.7   4.1   4.5  11.8  12.4
# 9   2010   Municipal       Rural  4.5  13.6  16.8  13.3  11.8    18  12.6
# 10  2010   Municipal       Total  2.9  11.1  14.7  10.1   9.5  18.2  14.7
# 11  2010   Municipal      Urbana  2.5  10.1  13.9   8.9   8.8  18.2  15.3
# 12  2010  Particular       Rural  8.2   7.3   8.3   6.3   6.3   8.9     6
# 13  2010  Particular       Total  2.1   2.2     2   1.9   2.1   4.8   5.5
# 14  2010  Particular      Urbana    2   2.2   1.9   1.9   2.1   4.8   5.5
# ...

# %%
filtered_dataset_fail_2009 = filtered_dataset_fail_from_2007_2010(2009)
filtered_dataset_fail_2009
# Out:
#      Ano        Rede Localização R1EF  R2EF  R3EF  4REF  R5EF  R6EF  R7EF  \
# 3   2009       Total       Total    3    11  12.8   8.7   8.7  16.5  13.6
# 4   2009    Estadual       Rural  3.4  13.3  14.2  11.1   9.9  15.5  12.1
# 5   2009    Estadual       Total  1.6   6.8   9.5     6   8.1  16.4  14.2
# 6   2009    Estadual      Urbana  1.5   6.3   9.1   5.7     8  16.5  14.3
# 7   2009     Federal       Rural   --     0     0     0     0   9.1    10
# 8   2009     Federal       Total  3.8   4.7   3.8   4.9   4.1  10.6  10.1
# 9   2009     Federal      Urbana  3.8   4.7   3.8     5   4.1  10.6  10.1
# 10  2009   Municipal       Rural  5.7  19.2  18.3  14.5    12  18.4  12.6
# 11  2009   Municipal       Total  3.4  13.5  15.5  10.7  10.1  19.3  15.2
# 12  2009   Municipal      Urbana  2.8  11.2  14.4   9.4   9.5  19.5    16
# 13  2009  Particular       Rural  9.5   8.6   7.7   8.1   6.4  10.1   6.8
# 14  2009  Particular       Total  2.1   2.3     2   1.9   2.2   4.6   5.5
# ...

# %%
filtered_dataset_fail_2008 = filtered_dataset_fail_from_2007_2010(2008, skiprows=5)
filtered_dataset_fail_2008
# Out:
#      Ano    Rede Localização R1EF  R2EF  R3EF  4REF  R5EF  R6EF  R7EF  R8EF  \
# 3   2008   Rural    Estadual  4.5    16    16  10.8    12  16.2  12.6  10.2
# 4   2008   Rural     Federal   --  14.3     0     0   7.7   8.3     0  16.7
# 5   2008   Rural   Municipal    7  22.8  19.9  15.6  12.5  19.1  13.4   9.7
# 6   2008   Rural  Particular  4.6  17.5   7.6   6.9   6.8     9   6.9     6
# 7   2008   Rural     Publico  6.8  22.4  19.6  15.3  12.5  18.6  13.3   9.8
# 8   2008   Rural       Total  6.8  22.3  19.5  15.2  12.5  18.5  13.2   9.7
# 9   2008   Total    Estadual  1.9   8.3  10.7   6.6   9.5  17.4  15.3  13.3
# 10  2008   Total     Federal    3   5.2     5   3.4   5.4  11.5   9.8  12.4
# 11  2008   Total   Municipal  4.1  15.4  16.1    11  10.4  19.2  15.2  11.5
# 12  2008   Total  Particular  1.8   2.3   1.9   1.8   2.1   4.5   5.3   5.1
# 13  2008   Total     Publico  3.7  13.8  14.9   9.9  10.1  18.2  15.2  12.5
# ...

# %%
filtered_dataset_fail_2007 = filtered_dataset_fail_from_2007_2010(2007, skiprows=5)
filtered_dataset_fail_2007
# Out:
#      Ano    Rede Localização R1EF  R2EF  R3EF  4REF  R5EF  R6EF  R7EF  R8EF  \
# 3   2007   Rural    Estadual    4  17.5  16.4  10.8  14.4  16.7  13.3   9.9
# 4   2007   Rural     Federal  NaN    10  11.1     0     0  28.6   NaN     0
# 5   2007   Rural   Municipal  8.4  24.3  19.9  15.7  12.4  17.8  12.2   8.8
# 6   2007   Rural  Particular  4.6    16   6.8   6.6   7.6   7.9   6.7   5.2
# 7   2007   Rural     Publico  8.1  23.9  19.6  15.3  12.6  17.6  12.4     9
# 8   2007   Rural       Total    8  23.8  19.6  15.3  12.5  17.5  12.4     9
# 9   2007   Total    Estadual  2.6  10.2  11.5   7.2  10.7  17.1  14.7  12.8
# 10  2007   Total     Federal  4.8   5.2   4.8   4.8   4.3    10  13.5  12.1
# 11  2007   Total   Municipal  4.6  16.4  16.1  11.4  10.6  18.2    14  10.7
# 12  2007   Total  Particular    2   2.3   1.9   1.7     2   4.1   4.9   4.8
# 13  2007   Total     Publico  4.2    15    15  10.4  10.6  17.6  14.4    12
# ...

# %%
fails = [filtered_dataset_fail_2020, filtered_dataset_fail_2019, filtered_dataset_fail_2018, filtered_dataset_fail_2017, filtered_dataset_fail_2016,
         filtered_dataset_fail_2015, filtered_dataset_fail_2014, filtered_dataset_fail_2013, filtered_dataset_fail_2012, filtered_dataset_fail_2011,
         filtered_dataset_fail_2010, filtered_dataset_fail_2009, filtered_dataset_fail_2008, filtered_dataset_fail_2007]

fail_dataset = pd.concat(fails)
fail_dataset.head()
# Out:
#     Ano Localização     Rede R_EF_Total R1EF R2EF R3EF 4REF R5EF R6EF R7EF  \
# 3  2020       Total    Total        0.8  0.4  0.5  0.7  0.5  0.7    1  1.1
# 4  2020      Urbana    Total        0.8  0.4  0.5  0.7  0.5  0.6  1.1  1.1
# 5  2020       Rural    Total        0.7  0.2  0.3  0.8  0.6  1.1  0.9  0.8
# 6  2020       Total  Federal        0.8  0.6    0  0.2  0.5  0.1  0.6    1
# 7  2020      Urbana  Federal        0.8  0.6    0  0.2  0.5  0.1  0.6    1
#
#   R8EF R9EF RTotal - EM  R1EM R2EM R3EM R4EM RNão-Seriado
# 3    1  1.1         2.7   3.2  2.1  2.6  6.3          6.1
# 4    1  1.2         2.7   3.2  2.2  2.6  6.3          6.9
# 5  0.7  0.8         2.6   3.2  1.9  2.4  5.2          3.2
# 6  1.5  0.4          10  15.4  8.3  6.4  6.1          6.8
# 7  1.5  0.4         9.1  14.1  7.7  5.8  6.3          6.2

# %%
fail_dataset.Rede.unique()
# Out:
# array(['Total', 'Federal', 'Estadual', 'Municipal', 'Privada', 'Pública',
#        'Particular', 'Rural', 'Urbana', 'Publico'], dtype=object)

# %%
fail_dataset.Localização.unique()
# Out:
# array(['Total', 'Urbana', 'Rural', 'Publico', 'Particular', 'Municipal',
#        'Federal', 'Estadual', 'Privada'], dtype=object)

# %%
fail_dataset.Ano.unique()
# Out:
# array([2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010,
#        2009, 2008, 2007], dtype=object)

# %%
fail_dataset.to_csv(path_or_buf='data/fail_dataset.csv', index=False)
